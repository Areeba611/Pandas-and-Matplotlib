# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import *
x =linspace(-3, 3, 30)
plt.plot(x, sin(x),'brown')
plt.plot(x, cos(x), 'r-')
plt.plot(x, -sin(x), 'g--')
plt.plot(x,-cos(x),'y:')
print(plt.show())
plt.subplot(2,2,1)
plt.title('subplot(2,2,1)')
plt.plot(x,sin(x),'brown')
plt.subplot(2,2,2)
plt.title('subplot(2,2,2)')
plt.plot(x,cos(x),'r-')
plt.subplot(2,2,3)
plt.title('subplot(2,2,3)')
plt.plot(x,-sin(x),'g--')
plt.subplot(2,2,4)
plt.title('subplot(2,2,4)')
plt.plot(x,-cos(x),'y:')
# Out:
# None
